# %%
import pandas as pd
import numpy as np
import codecs
import io
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud

# %%
def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

class SimpleGroupedColorFunc(object):
    """Create a color function object which assigns EXACT colors
       to certain words based on the color to words mapping

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.word_to_color = {word: color
                              for (color, words) in color_to_words.items()
                              for word in words}

        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)

# %%
#m='5000-5gram-l1_'
#m='10000-5gram-l1_'
#m='1000-2gram-l1_class1feat’ #bare til filnavnet på koefficientfilen


# make multiclass workable
def make_cloud(filename, n, num_classes):
    m = filename
    #n = 100


    colors = ('#BC4345', '#96ADC7')
    
    coefs = pd.read_csv(filename, sep='\t') #pd.read_csv('coefs'+m+'.csv', sep='\t')
    coefs.columns = [s.replace('_', ' ') for s in coefs.columns]
    
    
    for i in range(num_classes):
    
        coefs = coefs[i:i+1].T
        coefsav = pd.DataFrame(coefs.mean(axis=1), columns=['coef']) #denne skal du ikke bruge
        coefsav['absol'] = abs(coefsav)
        #coefsav['stdev'] = coefs.std(axis=1)
        #coefsav['mean-std'] = coefsav.absol - coefsav.stdev
        coefsav.sort_values(by='coef', inplace=True, ascending=False)
        print(coefsav.head(10))
        print(coefsav.tail(10))

        wordcloud = WordCloud(background_color="white", collocations=True, width = 800, height = 800)
        wordcloud.generate_from_frequencies(frequencies=merge_two_dicts(coefsav.head(n).to_dict(orient='dict')['absol'], coefsav.tail(n).to_dict(orient='dict')['absol']))
        color_to_words = {}
        color_to_words[colors[0]] = list(coefsav.loc[coefsav.coef<0].index)
        color_to_words[colors[1]] = list(coefsav.loc[coefsav.coef>0].index)


        default_color = 'gray'
        grouped_color_func = SimpleGroupedColorFunc(color_to_words, default_color)
        wordcloud.recolor(color_func=grouped_color_func)

        fig = plt.figure(figsize=[6,6])
        ax = fig.add_subplot(111)
        ax.imshow(wordcloud, interpolation="bilinear")
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        ax.set_frame_on(False)

        plt.savefig('wordcloud_'+m+'.pdf', bbox_inches = 'tight', pad_inches = 0, dpi=600)
        plt.show()

# %%
# positive coefs should be "towards" 1, and negative is "towards" 0.
# in kaggle dataset, 1 is "unreliable".
make_cloud("allcoefs_10000-5gram-l1_1000iter.csv", 100, 1)
# Out:
#               coef     absol
# 2016      0.394315  0.394315
# hillary   0.267130  0.267130
# october   0.248447  0.248447
# us        0.219025  0.219025
# november  0.211233  0.211233
# anti      0.182823  0.182823
# com       0.155778  0.155778
# share     0.152381  0.152381
# source    0.146631  0.146631
# clinton   0.133951  0.133951
#                             coef     absol
# president donald       -0.144718  0.144718
# president donald trump -0.145054  0.145054
# ms                     -0.151147  0.151147
# said                   -0.176513  0.176513
# 2017                   -0.195823  0.195823
# follow                 -0.228573  0.228573
# mr                     -0.252742  0.252742
# on twitter             -0.255938  0.255938
# twitter                -0.266830  0.266830
# breitbart              -0.293974  0.293974

# %%
classes = ['barely-true','false','half-true','mostly-true','pants-fire','true']
#make_cloud("liar_coefs_10000feats_5gram-l1.csv", 100)

# %%
coefs = pd.read_csv("liar_coefs_10000feats_5gram-l1.csv", sep='\t')
coefs.columns = [s.replace('_', ' ') for s in coefs.columns]
#print(coefs.isnull().values.any())
#print(len(coefs))
#print(len(classes))
coefs["class_labels"] = classes
coefs.set_index("class_labels", inplace=True)
coefs = coefs.T
false = coefs.sort_values(by='false', ascending=False)
false = false["false"]
print(false.head(10))
print(false.tail(10))

# check up on logreg multiclass understanding of coef values
# Out:
# False
# 6
# 6
# debunked        2.801328
# never asked     2.619117
# vaccines        2.573224
# as it           2.550316
# for the past    2.387442
# destroyed       2.384117
# regulation      2.261119
# the 11          2.231280
# supporter       2.072337
# the crime       1.974049
# Name: false, dtype: float64
# was just        -1.387832
# paid for        -1.389211
# products        -1.441600
# federal law     -1.456339
# to let          -1.532681
# many of         -1.550490
# 60 percent of   -1.660313
# tax on          -1.736214
# privatize       -2.073705
# clinton said    -2.093048
# Name: false, dtype: float64

# %%
make_cloud("liar_coefs_10000feats_5gram-l1.csv", 100, 6)
# Out:
#                   coef     absol
# spending in   2.863813  2.863813
# congress and  2.337183  2.337183
# same job      2.312416  2.312416
# blocking      2.217627  2.217627
# by voting     2.002766  2.002766
# faith         1.984978  1.984978
# respect       1.955607  1.955607
# of the nra    1.929476  1.929476
# on illegal    1.920397  1.920397
# along         1.893795  1.893795
#                    coef     absol
# gasoline      -1.301992  1.301992
# in any        -1.353599  1.353599
# for president -1.354077  1.354077
# could get     -1.355109  1.355109
# found that    -1.372368  1.372368
# separate      -1.438419  1.438419
# science       -1.567135  1.567135
# has lost      -1.578984  1.578984
# close         -1.723629  1.723629
# to say        -1.949809  1.949809
#    coef  absol
# 0   0.0    0.0
#    coef  absol
# 0   0.0    0.0
# /anaconda/lib/python3.6/site-packages/wordcloud/wordcloud.py:390: RuntimeWarning: invalid value encountered in double_scalars
#   for word, freq in frequencies]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-93cb67909ae6> in <module>()
# ----> 1 make_cloud("liar_coefs_10000feats_5gram-l1.csv", 100, 6)
#
# <ipython-input-38-6eda06462638> in make_cloud(filename, n, num_classes)
#      28
#      29         wordcloud = WordCloud(background_color="white", collocations=True, width = 800, height = 800)
# ---> 30         wordcloud.generate_from_frequencies(frequencies=merge_two_dicts(coefsav.head(n).to_dict(orient='dict')['absol'], coefsav.tail(n).to_dict(orient='dict')['absol']))
#      31         color_to_words = {}
#      32         color_to_words[colors[0]] = list(coefsav.loc[coefsav.coef<0].index)
#
# /anaconda/lib/python3.6/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     463             if rs != 0:
#     464                 font_size = int(round((rs * (freq / float(last_freq))
# --> 465                                        + (1 - rs)) * font_size))
#     466             if random_state.random() < self.prefer_horizontal:
#     467                 orientation = None
#
# ValueError: cannot convert float NaN to integer
