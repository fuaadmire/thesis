# %%
import numpy as np
import codecs
#import glob
from sklearn.model_selection import train_test_split
import pandas as pd
from nltk import word_tokenize
import h5py
import os
#os.environ['KERAS_BACKEND'] = 'theano'
import keras
from keras.preprocessing import sequence
from keras.layers import Embedding, Input, Dense, LSTM, TimeDistributed
from keras.models import Model

# %%
keras.backend.backend()
# Out:
# 'theano'

# %%
data = codecs.open("data/kaggle_trainset.txt", 'r', 'utf-8').read().split('\n')
data = data[:20800]
data = [s.lower() for s in data]

labels = codecs.open("data/kaggle_train_labels.txt", 'r', 'utf-8').read().split('\n')
labels = labels[:20800]
labels = np.array([int(i) for i in labels])

train, dev, train_lab, dev_lab = train_test_split(data, labels, test_size=0.33, random_state=42)

# %%
train = [word_tokenize(i.lower()) for i in train]
dev = [word_tokenize(i.lower()) for i in dev]

# %%
# using the mean length of documents as max_doc_length for now
max_doc_length = int(np.round(np.mean([len(paragraph) for paragraph in train])))
print(max_doc_length)
num_time_steps = max_doc_length
# Out:
# 879

# %%
word_to_idx = {}
all_train_tokens = []
for i in train: 
    #sent = word_tokenize(i.lower())
    #all_train_tokens.append(sent)
    for word in i:
        all_train_tokens.append(word)
        #if word not in word_to_idx:
           # word_to_idx[word] = len(word_to_idx)+1 # making the first id is 1, so that I can pad with zeroes.

#print(sent)
#print(train.shape)
#print(word_to_idx)
vocab = set(all_train_tokens)
print(len(vocab))
id2word = {i+1: word for i, word in enumerate(vocab)} # making the first id is 1, so that I can pad with zeroes.
#Add ‘UNK' til vocab
[[id2word.get(word, "UNK") for word in sent] for sent in dev]
word2id = {v: k for k, v in id2word.items()}
vocab_size = len(vocab)


#vocab_size = len(word_to_idx)
#print(vocab_size)

#idx_to_word = {v: k for k, v in word_to_idx.items()}
# Out:
# 184604

# %%
word2id
# Out:
# {'pittsburg': 1,
#  'eurasienne': 2,
#  'marine-run': 3,
#  'everybody.': 4,
#  'faces': 5,
#  'transocean': 6,
#  'dizzy': 7,
#  'idefy': 8,
#  'disbanding': 9,
#  'monaco': 10,
#  'srivastav': 11,
#  'fértil': 12,
#  'observa': 13,
#  "'help": 14,
#  'streetlight': 15,
#  'head.more': 16,
#  'donuts': 17,
#  'threat.': 18,
#  'saeedi': 19,
#  'ripples': 20,
#  'government-in-exile': 21,
#  '-23.5': 22,
#  'incubándose': 23,
#  'iâ€™d': 24,
#  'frilly': 25,
#  'army\x94': 26,
#  'закончилось': 27,
#  'знал': 28,
#  'backslapping': 29,
#  'served.': 30,
#  'nvc': 31,
#  'jacksonian': 32,
#  'finishing': 33,
#  '…gauldin': 34,
#  'eschmidt': 35,
#  'currency-hedged': 36,
#  'joueuses': 37,
#  'america.conspiracy': 38,
#  'dentist': 39,
#  'tumin': 40,
#  'pixies': 41,
#  'siglo': 42,
#  'magaziner': 43,
#  'matured.i': 44,
#  'stenciled': 45,
#  'guber': 46,
#  'passionflower': 47,
#  'rafters': 48,
#  'формального': 49,
#  'londonbridge': 50,
#  'nixon-kissinger': 51,
#  'solaris': 52,
#  'hogsett': 53,
#  'kurdewan': 54,
#  '.stuff': 55,
#  'empleó': 56,
#  'varma': 57,
#  'regime.over': 58,
#  'incandescent': 59,
#  'generis': 60,
#  'preferentemente': 61,
#  'composer': 62,
#  'pennant': 63,
#  '176': 64,
#  'возбуждении': 65,
#  'urgency': 66,
#  'caen': 67,
#  'sportliche': 68,
#  '86.29': 69,
#  'lowercase': 70,
#  'sonographer': 71,
#  '1,131': 72,
#  'senators': 73,
#  'grams': 74,
#  'alfra': 75,
#  'nearly-complete': 76,
#  'butchering': 77,
#  'tg4': 78,
#  'violations.this': 79,
#  'explode.erdogan': 80,
#  'auditors': 81,
#  'red-shifted': 82,
#  'barreiras': 83,
#  'isotrop': 84,
#  'mexichem': 85,
#  'negli': 86,
#  'warbelow': 87,
#  '1,112,000': 88,
#  'gmu': 89,
#  '2,994': 90,
#  'increase/': 91,
#  'nicholls': 92,
#  'posent': 93,
#  'contener': 94,
#  'detriment': 95,
#  'angiology': 96,
#  'wetbacks': 97,
#  'pointers': 98,
#  'miami': 99,
#  'squabbling': 100,
#  'dirigida': 101,
#  'die…or': 102,
#  'efraim': 103,
#  'eola': 104,
#  'danscavino': 105,
#  'evers': 106,
#  'yahvé': 107,
#  'fibe': 108,
#  'القومية': 109,
#  'mufti': 110,
#  'str': 111,
#  'yalta': 112,
#  'grandstander': 113,
#  'adults.': 114,
#  'breathes': 115,
#  'pickering': 116,
#  'leaders–dubbed': 117,
#  'κολέγιο': 118,
#  'misfiling': 119,
#  'holanda': 120,
#  'milliliter': 121,
#  'alabaster': 122,
#  "l'alerte": 123,
#  'samlet': 124,
#  'tlapanco': 125,
#  'dishonoured': 126,
#  'minorities': 127,
#  'dolo': 128,
#  'sagt': 129,
#  'democrat.doug': 130,
#  'applicability': 131,
#  'iridescence': 132,
#  'gmmr': 133,
#  'ten-point': 134,
#  'organizations': 135,
#  'toeing': 136,
#  'incitement.': 137,
#  'problems.obama\x92s': 138,
#  'sota': 139,
#  'nezavisimaya': 140,
#  'liderleri': 141,
#  'sarachild': 142,
#  'refinance': 143,
#  '\x91justice\x92': 144,
#  '269': 145,
#  'paperweight': 146,
#  'özel': 147,
#  'moscow-delhi': 148,
#  'pfass': 149,
#  'counterpane': 150,
#  'busier': 151,
#  'granholm': 152,
#  'slapp': 153,
#  'sands': 154,
#  'playback': 155,
#  'ceremonial.despite': 156,
#  'davids': 157,
#  'racier': 158,
#  'cellarer': 159,
#  'takahara': 160,
#  'mismo.tomado': 161,
#  'aggravating': 162,
#  'банка': 163,
#  'rotundo': 164,
#  'negative': 165,
#  'logos': 166,
#  'carbohydrate': 167,
#  'числиться': 168,
#  'followed.': 169,
#  'unbuckled': 170,
#  'animales': 171,
#  'gap-challenged': 172,
#  'hontiveros': 173,
#  'rejectionist': 174,
#  'privatization': 175,
#  'speights': 176,
#  'полноценная': 177,
#  'vongerichten': 178,
#  'strays': 179,
#  'kravet': 180,
#  'steerable': 181,
#  'marbling': 182,
#  'ararat': 183,
#  'remonstrated': 184,
#  'kneelers': 185,
#  'pintan': 186,
#  'transitory': 187,
#  'derrotado': 188,
#  'bizarreness': 189,
#  'pic.twitter.com/w5jwlpzhbf': 190,
#  'thorny': 191,
#  'dimension': 192,
#  'headshot': 193,
#  'imprisoned': 194,
#  'successively': 195,
#  'girişirler.ne': 196,
#  'theologians': 197,
#  'dicephaly': 198,
#  'serious.especially': 199,
#  '.22': 200,
#  'هلال': 201,
#  'predatory': 202,
#  'protocolo': 203,
#  'fackrell': 204,
#  'age…or': 205,
#  'oafs': 206,
#  'transparentes': 207,
#  'banchero': 208,
#  'zirp': 209,
#  'monsatan': 210,
#  'неслучайно': 211,
#  'deferring': 212,
#  'cyberspying': 213,
#  'ortadan': 214,
#  'jauntily': 215,
#  'verfolgen': 216,
#  'leavenworth': 217,
#  'sxsw': 218,
#  'pluralist': 219,
#  'galati': 220,
#  'vencedor': 221,
#  'barked': 222,
#  'that.ss': 223,
#  'известные': 224,
#  'доводит': 225,
#  'shore.this': 226,
#  'организмов': 227,
#  'tester': 228,
#  'transcript': 229,
#  'metrosexual': 230,
#  'عدد': 231,
#  '21,1992': 232,
#  'outperforms': 233,
#  'fiascos': 234,
#  'giphy': 235,
#  'забитый': 236,
#  'arrêt': 237,
#  'private-public': 238,
#  'crocuses': 239,
#  'портативных': 240,
#  'такому': 241,
#  'peekaboo': 242,
#  'de-monitzation': 243,
#  'broke.when': 244,
#  'phu': 245,
#  'allowed.it': 246,
#  'mbah': 247,
#  'dispel': 248,
#  'geekwire': 249,
#  'bayrock': 250,
#  'lobiondo': 251,
#  'occur—which': 252,
#  'factory-made': 253,
#  'blessgo': 254,
#  'ακύρωσε': 255,
#  'prom': 256,
#  'germany.with': 257,
#  'abdo': 258,
#  'outcomes': 259,
#  'lse': 260,
#  'omologo': 261,
#  'parity': 262,
#  'humored': 263,
#  'cija': 264,
#  'conveying': 265,
#  'selbstverwaltern': 266,
#  'redeten': 267,
#  'apple-flavored': 268,
#  'defense': 269,
#  'quenched': 270,
#  'longshot': 271,
#  'calculable': 272,
#  'produce': 273,
#  'tantalizingly': 274,
#  'video-game-like': 275,
#  'subversive': 276,
#  'endures.': 277,
#  'azdihar': 278,
#  'growled': 279,
#  '85-90': 280,
#  'tent.also': 281,
#  'mime': 282,
#  'stop.this': 283,
#  'gyre': 284,
#  'fountainhead': 285,
#  'editorialize': 286,
#  'soon.': 287,
#  'laissera': 288,
#  'entretien': 289,
#  'deana': 290,
#  'broiling': 291,
#  'праздновать': 292,
#  'on-demand': 293,
#  "l'iran": 294,
#  'jm': 295,
#  'reignofapril': 296,
#  'crotone': 297,
#  'banbang': 298,
#  'الرغم': 299,
#  'trailers': 300,
#  'αλληλογραφίας': 301,
#  'outlined': 302,
#  "'falls": 303,
#  'undersize': 304,
#  'всякий': 305,
#  'antiseismic': 306,
#  'σύλλογο': 307,
#  'ors': 308,
#  'bilderberger': 309,
#  'ghochar': 310,
#  'crossing.': 311,
#  'vulnerability/': 312,
#  'iamsnokeo_o': 313,
#  'bourgh': 314,
#  'crit\xadi\xadcism': 315,
#  'findings.timid': 316,
#  'crevv.': 317,
#  'womansvibe.com': 318,
#  'alladin': 319,
#  'lofty': 320,
#  'non-mainstream': 321,
#  'hacia': 322,
#  'prosciutto': 323,
#  'сложностей': 324,
#  'então': 325,
#  'afterwords': 326,
#  'denominados': 327,
#  'tarah': 328,
#  'hatzi': 329,
#  'liliputh': 330,
#  'anxiety.': 331,
#  'ребром': 332,
#  'pro-rebel': 333,
#  '136316': 334,
#  'agency-specific': 335,
#  '\x93strategic': 336,
#  '2.33': 337,
#  'chastisement': 338,
#  'испытательного': 339,
#  'аль-утаби': 340,
#  'evitava': 341,
#  'dratel': 342,
#  'sackett': 343,
#  'annes': 344,
#  'philanthropist': 345,
#  'lang=eng': 346,
#  'placenta': 347,
#  'baseldon': 348,
#  'impotent.the': 349,
#  '16-30': 350,
#  'sabat': 351,
#  'victorious': 352,
#  'nnu': 353,
#  'arches': 354,
#  'behaviour': 355,
#  'air.russia': 356,
#  'swissair': 357,
#  'bielski': 358,
#  'fundamentals': 359,
#  'группы': 360,
#  'genomes': 361,
#  'né': 362,
#  'estrenó': 363,
#  '2.05': 364,
#  'hatte': 365,
#  'avani': 366,
#  'revenant': 367,
#  'jerusalemforever': 368,
#  'artmaking': 369,
#  'jolt': 370,
#  '43-jährige': 371,
#  'prather': 372,
#  'humbles': 373,
#  'clandestinely': 374,
#  'schaeffer': 375,
#  'toscana': 376,
#  'idea\x97offered': 377,
#  'russia…continues': 378,
#  'woofed': 379,
#  'hyperacusis': 380,
#  'sheild': 381,
#  'penises': 382,
#  'goldilocks': 383,
#  'reformar': 384,
#  'freebies.': 385,
#  'легальным': 386,
#  '1910': 387,
#  'pollution': 388,
#  '152.59': 389,
#  'creation': 390,
#  'albergo': 391,
#  'hmv': 392,
#  'defeats': 393,
#  'inacio': 394,
#  'вездесущей': 395,
#  'bullets': 396,
#  'bloomberg/gata': 397,
#  'sla': 398,
#  'haworth': 399,
#  '/span': 400,
#  'jeffpeguescbs': 401,
#  'everyone.soon': 402,
#  'hour–': 403,
#  'scrambled': 404,
#  'rahm': 405,
#  'anglosphere': 406,
#  'إلا': 407,
#  'spiritaero.com': 408,
#  'ужасной': 409,
#  'وسياسته': 410,
#  'clinton/weiner': 411,
#  'news-report': 412,
#  'trafficking-': 413,
#  '£200': 414,
#  'unorganized': 415,
#  'ultra-accommodative': 416,
#  'bajan': 417,
#  'unambiguously': 418,
#  'встречу': 419,
#  'waight': 420,
#  '323': 421,
#  'self-worker': 422,
#  'point.technology': 423,
#  'artofthesteal': 424,
#  'والاتجار': 425,
#  'bohmian': 426,
#  'monteiro': 427,
#  'cantidad': 428,
#  'coneixença': 429,
#  'vey': 430,
#  'centralised': 431,
#  'funnier': 432,
#  'then-candidate': 433,
#  'entziehen': 434,
#  'azcentral': 435,
#  'prestige.': 436,
#  'federalist': 437,
#  'pipeline': 438,
#  '=he': 439,
#  'jakaya': 440,
#  'jerking': 441,
#  'jolie': 442,
#  'bielicki': 443,
#  'khamer': 444,
#  'brazen': 445,
#  '12:19': 446,
#  'gobbledygook': 447,
#  'apartness': 448,
#  'beside': 449,
#  'desegregating': 450,
#  'mårten': 451,
#  'late-breakers': 452,
#  'earnings': 453,
#  'clef': 454,
#  'tort': 455,
#  'ka-boom': 456,
#  'целом': 457,
#  'unconquered': 458,
#  'riegel': 459,
#  'snowballing': 460,
#  'invader.': 461,
#  '15.1.106.15': 462,
#  'awwad': 463,
#  'minimart': 464,
#  'hinduism': 465,
#  'interstitial': 466,
#  'exteriors': 467,
#  'barbora': 468,
#  '2012.this': 469,
#  'the…in': 470,
#  'memorize': 471,
#  "'safe": 472,
#  'actions.given': 473,
#  'palacio': 474,
#  'كاف': 475,
#  'squirtles': 476,
#  'azita': 477,
#  '3,930': 478,
#  'frey': 479,
#  'neoliberalism–so': 480,
#  'wife…which': 481,
#  'pressurization': 482,
#  'attentiveness': 483,
#  'adapt.': 484,
#  'setback': 485,
#  'long-cherished': 486,
#  "'naughty": 487,
#  'ez-zor': 488,
#  '27mph': 489,
#  'abb': 490,
#  'mimisam28': 491,
#  'sensuality': 492,
#  'icj': 493,
#  'constructors': 494,
#  'differently-abled': 495,
#  '361.242': 496,
#  'galerie': 497,
#  'pleasantry': 498,
#  'scriveners': 499,
#  'weitgehend': 500,
#  'front-led': 501,
#  'sumlin': 502,
#  'uncouthly': 503,
#  'uruguayans': 504,
#  'extortionate': 505,
#  'divey': 506,
#  '184,000': 507,
#  'fälle': 508,
#  'kauanui': 509,
#  '9:22am': 510,
#  'dextroamphetamine': 511,
#  'ntaryamira': 512,
#  'thousand': 513,
#  'билет': 514,
#  'gawks': 515,
#  'scalise': 516,
#  'niveau': 517,
#  'bajpai': 518,
#  'rovera': 519,
#  'timperlake': 520,
#  'consequence': 521,
#  'friedlander': 522,
#  'reestructurar': 523,
#  'changer': 524,
#  'tenté': 525,
#  'slug': 526,
#  'φιλοδοξούσε': 527,
#  'shouting': 528,
#  'fishawy': 529,
#  'поставках': 530,
#  'dune': 531,
#  'narcotrafficking': 532,
#  'taxperience': 533,
#  'extra': 534,
#  'الوزارة': 535,
#  'whitewashed': 536,
#  'coaster': 537,
#  'риа': 538,
#  'resanaron': 539,
#  'domino': 540,
#  'direction…wtf': 541,
#  'muslims….you': 542,
#  '26-2-2016': 543,
#  'aloo': 544,
#  'chemo': 545,
#  'un-islamic': 546,
#  'guarding': 547,
#  '1811': 548,
#  'sorununu': 549,
#  'lureri': 550,
#  'corpses': 551,
#  'said.in': 552,
#  'lumens': 553,
#  'theoretical': 554,
#  'seibert': 555,
#  'douchebag': 556,
#  'rispetti': 557,
#  'alienation': 558,
#  'mumming': 559,
#  'devils': 560,
#  'griping': 561,
#  'seréis': 562,
#  'lesage': 563,
#  'rubbles': 564,
#  '24': 565,
#  'thabit': 566,
#  'frequency/microwave': 567,
#  'клиентов': 568,
#  'размышляют': 569,
#  'freys': 570,
#  'движении': 571,
#  'anti-imperial/capitalist': 572,
#  'remixes': 573,
#  'second-cheapest': 574,
#  'vinader': 575,
#  'helal': 576,
#  'одобрении': 577,
#  'القضائية': 578,
#  'thereness..a': 579,
#  'wählt': 580,
#  'refutes': 581,
#  'arfang': 582,
#  'enfin': 583,
#  'bouriatie': 584,
#  'list': 585,
#  'rellenas': 586,
#  'ghazni': 587,
#  'hrco=': 588,
#  'hochaufmerksam': 589,
#  'joandarc': 590,
#  'decisions': 591,
#  'gig.': 592,
#  'españolistas': 593,
#  'non-étatiques': 594,
#  'участвуете': 595,
#  'strada': 596,
#  'cinayet': 597,
#  'velociraptors': 598,
#  'internship': 599,
#  'bismack': 600,
#  'difícilmente': 601,
#  'идеалу': 602,
#  'kidnapping.allegedly': 603,
#  'bombards': 604,
#  'added.meanwhile': 605,
#  'omarova': 606,
#  'bonsais': 607,
#  'gyory': 608,
#  'foeticide': 609,
#  'shingle': 610,
#  'warmongerers': 611,
#  'hinweisen': 612,
#  '3-3': 613,
#  'lenglen': 614,
#  'ولدت': 615,
#  '518': 616,
#  'goncharov': 617,
#  '44,106': 618,
#  'iran–contra': 619,
#  'попытке': 620,
#  'australian': 621,
#  'mortati': 622,
#  'buff': 623,
#  'be—but': 624,
#  'anlauf': 625,
#  'shevardnadze': 626,
#  'unbestimmte': 627,
#  '13:16,17': 628,
#  'وسمحت': 629,
#  'longerich': 630,
#  'pleasuring': 631,
#  'progenitor': 632,
#  '\x93moderate': 633,
#  'if—or': 634,
#  'dunlop': 635,
#  'kilometres': 636,
#  'enseña': 637,
#  'bianchi': 638,
#  'flag-hoisting': 639,
#  'nonimmigrants': 640,
#  '1q23': 641,
#  'vector': 642,
#  'dehumanizing': 643,
#  'киборгов': 644,
#  'hoosier2012': 645,
#  'videomaterial': 646,
#  'farmers.the': 647,
#  'заплатили': 648,
#  'macuto': 649,
#  'maligned': 650,
#  'scrupulous': 651,
#  'llevadas': 652,
#  'industria': 653,
#  'minus': 654,
#  'malia': 655,
#  'inna': 656,
#  'douse': 657,
#  'kidspot': 658,
#  'emmer': 659,
#  'результат': 660,
#  'учёных': 661,
#  'soei': 662,
#  'individual—a': 663,
#  'spoiling': 664,
#  'refund': 665,
#  'freshdirect': 666,
#  'ballots.questions': 667,
#  'extent—what': 668,
#  'hoisting': 669,
#  'kgosi': 670,
#  '🙏🏻': 671,
#  'interlock': 672,
#  'shearman': 673,
#  'sophistry': 674,
#  'counterforce': 675,
#  'pennants': 676,
#  'arse.': 677,
#  'metals.': 678,
#  'night-vision': 679,
#  'readynutrition.com': 680,
#  'monthshttps': 681,
#  'plagues': 682,
#  'авиационный': 683,
#  'staying.such': 684,
#  'non-duplicate': 685,
#  'taboos.yet': 686,
#  'trump.corporate': 687,
#  'nato-wirtschaft': 688,
#  '2.income': 689,
#  'quantrek': 690,
#  'расширении': 691,
#  'prowl': 692,
#  'polygamous': 693,
#  'inversely': 694,
#  'friendliness': 695,
#  'acheter': 696,
#  'considère': 697,
#  'sued.they': 698,
#  'بقواعد': 699,
#  'памятник': 700,
#  'mafia.they': 701,
#  'amputated': 702,
#  'dcg': 703,
#  'pulpits': 704,
#  '10:42:53': 705,
#  '/cbs': 706,
#  '6.5': 707,
#  'issues.while': 708,
#  'riffs': 709,
#  'certainty': 710,
#  'misspent': 711,
#  'adresses': 712,
#  'onâ': 713,
#  'n.c.': 714,
#  'people—': 715,
#  'fries': 716,
#  'redo': 717,
#  'agustín': 718,
#  'scotches': 719,
#  'raids': 720,
#  'depoliticized': 721,
#  'uncork': 722,
#  'antigonish': 723,
#  'gusting': 724,
#  'olivet': 725,
#  'intelligence/military': 726,
#  'all-consuming': 727,
#  '92,830': 728,
#  'jewish-americans.kaplan': 729,
#  'mektig': 730,
#  'тянут': 731,
#  'klas-tv': 732,
#  'unterschiedlichen': 733,
#  'dips': 734,
#  'tranquillizers': 735,
#  'displaces': 736,
#  'promise…': 737,
#  'ene': 738,
#  'aantreden': 739,
#  'bombmakers': 740,
#  'wasser': 741,
#  'fetched.rumors': 742,
#  'pinkened': 743,
#  'glymp': 744,
#  'disinger': 745,
#  'garanganga': 746,
#  'kristin': 747,
#  'радиоактивный': 748,
#  'mädchen': 749,
#  '945.26': 750,
#  'enough…': 751,
#  'presign': 752,
#  'www.huffingtonpostforum.com': 753,
#  'reason.panic': 754,
#  'kimdotcom': 755,
#  'automaker': 756,
#  'templeton': 757,
#  'attested': 758,
#  'skeptical': 759,
#  'сделку': 760,
#  'cbd': 761,
#  'недопустимы': 762,
#  'yugoslavian': 763,
#  'sola': 764,
#  'syria.yet': 765,
#  'enough—then': 766,
#  '\x93mandate': 767,
#  'iddiasında': 768,
#  'heartburn': 769,
#  '\x93careless': 770,
#  'dunn': 771,
#  'extremists.trump': 772,
#  'disappear.': 773,
#  'speechwriters': 774,
#  'colostomy': 775,
#  'venditori': 776,
#  'lumumba': 777,
#  'común': 778,
#  'yes…it': 779,
#  'boujee.': 780,
#  'dynastic': 781,
#  'camp-horinek': 782,
#  'home-invasion': 783,
#  'district-wide': 784,
#  'philipp': 785,
#  'noted.a': 786,
#  'whim': 787,
#  'wcco': 788,
#  'amoral.': 789,
#  'ontmaskerd': 790,
#  'calculator.': 791,
#  'deglaciation': 792,
#  '.many': 793,
#  'aroma': 794,
#  'thesun.co.uk': 795,
#  'casualties.so': 796,
#  'perception': 797,
#  'кандидатом': 798,
#  'resuelta': 799,
#  'grenze': 800,
#  'maye-e': 801,
#  'confesaste': 802,
#  'away.those': 803,
#  'abc/post': 804,
#  'ubisoft': 805,
#  'despising': 806,
#  'choosy': 807,
#  'bizarrely-worded': 808,
#  'milliards': 809,
#  'insightful': 810,
#  'lieberman': 811,
#  'dis-incentive': 812,
#  'siebold': 813,
#  "'believe": 814,
#  'nastier': 815,
#  '62': 816,
#  'naked': 817,
#  'high-pitched': 818,
#  'areas.eighty-six': 819,
#  'window.': 820,
#  'tema.pero': 821,
#  'neuro-linguistic': 822,
#  'mars-wide': 823,
#  'temples': 824,
#  'hearn': 825,
#  'die-ins': 826,
#  'akbarzhon': 827,
#  'incrementar': 828,
#  'levando': 829,
#  'baby': 830,
#  'below': 831,
#  'repurposes': 832,
#  'dart': 833,
#  'zeigen': 834,
#  'erick': 835,
#  'frelimo': 836,
#  'advocate': 837,
#  'fusion': 838,
#  'multi-vector': 839,
#  '32gb': 840,
#  'liée': 841,
#  'medicine—not': 842,
#  'atheistical-anti-male-lesbian-feminism': 843,
#  '3:33:59': 844,
#  'pertenece': 845,
#  'reconditioned': 846,
#  '5100': 847,
#  'einziehen': 848,
#  'inauspicious': 849,
#  'overprescribing': 850,
#  'revelations': 851,
#  'amberg': 852,
#  'лаудер': 853,
#  'caracas': 854,
#  'codifying': 855,
#  'российско-американским': 856,
#  'rarefied': 857,
#  '2.37': 858,
#  'snoopgate': 859,
#  's—faults': 860,
#  'convict': 861,
#  'd-hawaii': 862,
#  'academia…': 863,
#  'available': 864,
#  'lavonda': 865,
#  '1876': 866,
#  'cooperriis': 867,
#  'grata': 868,
#  'agitator': 869,
#  '*86': 870,
#  'verdammt': 871,
#  'sparser': 872,
#  'black-sounding': 873,
#  'encrustation': 874,
#  'smokes': 875,
#  '//vicenews.com': 876,
#  'unaccustomed': 877,
#  'психологах': 878,
#  'n.morgan': 879,
#  '*72': 880,
#  'pation': 881,
#  'penned': 882,
#  'текущего': 883,
#  'jwj': 884,
#  'opec/m': 885,
#  'hamtramck': 886,
#  'shattered.': 887,
#  'الشمري': 888,
#  'shibley': 889,
#  'rolling-stone': 890,
#  '1bp': 891,
#  'helmets': 892,
#  'city-busting': 893,
#  'three-hour': 894,
#  'so.you': 895,
#  'employee\x92s': 896,
#  'presidency': 897,
#  'sombath': 898,
#  'loder': 899,
#  'text/plain': 900,
#  'indefinitely': 901,
#  'подталкивают': 902,
#  'kidnapping.': 903,
#  'vermeiden': 904,
#  'ourselves.you': 905,
#  'compiler': 906,
#  'disowns': 907,
#  'ka9skmlkkfccsnj0collb+mw9dvqgc2dpwphpgtyzlwg5tins2bkdv67qj4lysrm': 908,
#  '3rd': 909,
#  "'telmatobius": 910,
#  'landfill': 911,
#  'undertrykkelse': 912,
#  'dissented': 913,
#  'diyarbakir': 914,
#  'molestation.': 915,
#  'greenlight': 916,
#  'hieronymus': 917,
#  'offshore…': 918,
#  'помогут': 919,
#  'herons': 920,
#  'artnoir': 921,
#  'enthusiastically': 922,
#  'vestas': 923,
#  'липецкой': 924,
#  'чего-нибудь': 925,
#  'قوبلت': 926,
#  'underwater': 927,
#  'five-leg': 928,
#  'albie': 929,
#  'mae': 930,
#  'spécialisées': 931,
#  'self-flattering': 932,
#  'fructose': 933,
#  'beethoven—some': 934,
#  'booster': 935,
#  'conserving': 936,
#  'asthenia': 937,
#  'nonsupervisory': 938,
#  '11:59pm': 939,
#  'despaired': 940,
#  'ülkede': 941,
#  'predecessors': 942,
#  'weißen': 943,
#  'sub-conscious': 944,
#  'feras': 945,
#  'populistic': 946,
#  't-r-u-m-p': 947,
#  'mortal': 948,
#  'repetition': 949,
#  'antifa': 950,
#  'tombscientists': 951,
#  'g20': 952,
#  'sayimage': 953,
#  'russophobe': 954,
#  'uadrennial': 955,
#  'anesthetized': 956,
#  'itt': 957,
#  'transition': 958,
#  'exude': 959,
#  'идею': 960,
#  'manasrah': 961,
#  'scientifically': 962,
#  'govhowarddean': 963,
#  'bioshock': 964,
#  'aesop': 965,
#  'desilver': 966,
#  'refusé': 967,
#  'per\xadson\xadnel': 968,
#  'kayseri': 969,
#  'calendars': 970,
#  'campobasso': 971,
#  'longingly': 972,
#  '110913': 973,
#  'infosphere': 974,
#  'education': 975,
#  'tinkered': 976,
#  '_________________': 977,
#  'образуется': 978,
#  'fenced': 979,
#  'brigid': 980,
#  'cell…not': 981,
#  'hcg.': 982,
#  'wrongheaded': 983,
#  'microbiologist': 984,
#  'сентября': 985,
#  'nature-made': 986,
#  'minusválido': 987,
#  'alleviating': 988,
#  'חזן': 989,
#  'caperings': 990,
#  'streamline': 991,
#  'territory\x94': 992,
#  'antibacterial': 993,
#  'castleman': 994,
#  'chelan': 995,
#  're-allocation': 996,
#  'антимонопольной': 997,
#  'секретных': 998,
#  'livelifelouder': 999,
#  'monday.the': 1000,
#  ...}

# %%
id2word[2]
# Out:
# 'eurasienne'

# %%
# save Dict file containing the mapping from word ID to word (e.g. train.dict)
f = open("dict.txt","w+")
f.write( str(id2word) )
f.close()
# use tool from lstmvis to transform txt to .Dict file.

# %%
trainTextsSeq_list = []
for input_sequence in train:
    inputs = [word2id[w] for w in input_sequence]
    trainTextsSeq_list.append(inputs)
trainTextsSeq = np.array(trainTextsSeq_list)

# %%
# padding with max doc lentgh (mean length at the moment)
seq = sequence.pad_sequences(trainTextsSeq, maxlen=max_doc_length, dtype='int32', padding='post', truncating='post', value=0.0)

# %%
trainTextsSeq_flatten = np.array(seq).flatten()
hf = h5py.File("train.hdf5", "w")
hf.create_dataset('words', data=trainTextsSeq_flatten)
hf.close()

# %%
# Reshape y_train: 
y_train_tiled = np.tile(train_lab, (num_time_steps,1))
y_train_tiled = y_train_tiled.reshape(len(train_lab), num_time_steps , 1)

# %%
y_train_tiled.shape
# Out:
# (13936, 879, 1)

# %%
# num_cells: number of LSTM cells
num_cells = 100 # 100 for now, probably test best parameter through cross-validation
num_samples = len(train_lab)
embedding_size = 100 # also just for now..
num_epochs = 100
num_batch = 32 # also find optimal through cross-validation

# max_doc_length vectors of size embedding_size
myInput = Input(shape=(max_doc_length,), name='input') 
x = Embedding(output_dim=embedding_size, input_dim=vocab_size, input_length=max_doc_length)(myInput)
lstm_out = LSTM(num_cells, return_sequences=True)(x)
predictions = TimeDistributed(Dense(2, activation='softmax'))(lstm_out)
model = Model(inputs=myInput, outputs=predictions)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-a9cd8f4d59b7> in <module>()
#       8 # max_doc_length vectors of size embedding_size
#       9 myInput = Input(shape=(max_doc_length,), name='input')
# ---> 10 x = Embedding(output_dim=embedding_size, input_dim=vocab_size, input_length=max_doc_length)(myInput)
#      11 lstm_out = LSTM(num_cells, return_sequences=True)(x)
#      12 predictions = TimeDistributed(Dense(2, activation='softmax'))(lstm_out)
#
# NameError: name 'vocab_size' is not defined

# %% [markdown]
# From tutorial:
# Next, we need to reshape the document class labels. In many other usages such as POS tagging, the model emits a value for each input token, while in document classification, the model typically emits a value for each document. To make the class labels consistent with such model, we need to have a vector for each time step. We can reshape the original vector of class labels by repetition. That is, for instance in binary classification, if the sample is positive, all underlying words are labeled as 1, otherwise 0. Towards this goal, we can use tile function as follows:

# %%
print(seq.shape)
print(y_train_tiled.shape)
model.fit({'input': seq}, y_train_tiled, epochs=20, verbose=1)
# Out:
# (13936, 4514)
# (13936, 4514, 1)
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-e122d16edd02> in <module>()
#       1 print(seq.shape)
#       2 print(y_train_tiled.shape)
# ----> 3 model.fit({'input': seq}, y_train_tiled, epochs=20, verbose=1)
#       4 # ValueError: Error when checking input: expected input to have shape (4514,) but got array with shape (1,)
#
# /anaconda/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# /anaconda/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# /anaconda/lib/python3.6/site-packages/keras/backend/theano_backend.py in __call__(self, inputs)
#    1275     def __call__(self, inputs):
#    1276         assert isinstance(inputs, (list, tuple))
# -> 1277         return self.function(*inputs)
#    1278
#    1279
#
# /anaconda/lib/python3.6/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     901         try:
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#     905         except Exception:
#
# /anaconda/lib/python3.6/site-packages/theano/gof/vm.py in __call__(self)
#     299                 for thunk, node, old_storage in zip(self.thunks, self.nodes,
#     300                                                     self.post_thunk_clear):
# --> 301                     thunk()
#     302                     for old_s in old_storage:
#     303                         old_s[0] = None
#
# /anaconda/lib/python3.6/site-packages/theano/scan_module/scan_op.py in rval(p, i, o, n, allow_gc)
#     961         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     962                  allow_gc=allow_gc):
# --> 963             r = p(n, [x[0] for x in i], o)
#     964             for o in node.outputs:
#     965                 compute_map[o][0] = True
#
# /anaconda/lib/python3.6/site-packages/theano/scan_module/scan_op.py in execute(self, node, args, outs)
#    1333
#    1334             try:
# -> 1335                 fn()
#    1336             except Exception:
#    1337                 if hasattr(fn, 'position_of_error'):
#
# /anaconda/lib/python3.6/site-packages/theano/gof/vm.py in __call__(self)
#     254             try:
#     255                 for thunk, node in zip(self.thunks, self.nodes):
# --> 256                     thunk()
#     257             except Exception:
#     258                 link.raise_with_op(node, thunk)
#
# /anaconda/lib/python3.6/site-packages/theano/gof/op.py in rval(p, i, o, n)
#     890             # default arguments are stored in the closure of `rval`
#     891             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 892                 r = p(n, [x[0] for x in i], o)
#     893                 for o in node.outputs:
#     894                     compute_map[o][0] = True
#
# /anaconda/lib/python3.6/site-packages/theano/tensor/elemwise.py in perform(self, node, inputs, output_storage)
#     788             nout = ufunc.nout
#     789
# --> 790         variables = ufunc(*ufunc_args, **ufunc_kwargs)
#     791
#     792         if nout == 1:
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in impl(self, *inputs)
#    4022     def impl(self, *inputs):
#    4023         output_storage = [[None] for i in xrange(self.nout)]
# -> 4024         self.perform(None, inputs, output_storage)
#    4025         ret = utils.to_return_values([storage[0] for storage in
#    4026                                       output_storage])
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in perform(self, node, inputs, output_storage)
#    4018     def perform(self, node, inputs, output_storage):
#    4019         for storage, impl in zip(output_storage, self._impls):
# -> 4020             storage[0] = impl(inputs)
#    4021
#    4022     def impl(self, *inputs):
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in f(inputs)
#    3890
#    3891             def f(inputs):
# -> 3892                 return node.op.impl(*[p(inputs) for p in producers])
#    3893             memo[r] = f
#    3894             return f
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in <listcomp>(.0)
#    3890
#    3891             def f(inputs):
# -> 3892                 return node.op.impl(*[p(inputs) for p in producers])
#    3893             memo[r] = f
#    3894             return f
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in f(inputs)
#    3890
#    3891             def f(inputs):
# -> 3892                 return node.op.impl(*[p(inputs) for p in producers])
#    3893             memo[r] = f
#    3894             return f
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in <listcomp>(.0)
#    3890
#    3891             def f(inputs):
# -> 3892                 return node.op.impl(*[p(inputs) for p in producers])
#    3893             memo[r] = f
#    3894             return f
#
# /anaconda/lib/python3.6/site-packages/theano/scalar/basic.py in f(inputs)
#    3877                 idx = self.fgraph.inputs.index(r)
#    3878
# -> 3879                 def f(inputs):
#    3880                     return inputs[idx]
#    3881                 memo[r] = f
#
# KeyboardInterrupt:

# %%
model.layers.pop();
model.summary()
# Save the states via predict
inp = model.input
out = model.layers[-1].output
model_RetreiveStates = Model(inp, out)
states_model = model_RetreiveStates.predict(trainTextsSeq, batch_size=num_batch)
print(states_model.shape)

# %%
# Flatten first and second dimension for LSTMVis
states_model_flatten = states_model.reshape(num_samples * num_time_steps, num_cells)

hf = h5py.File("states.hdf5", "w")
hf.create_dataset('states1', data=states_model_flatten)
hf.close()
